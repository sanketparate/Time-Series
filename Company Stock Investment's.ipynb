# %% [markdown]
# # <b><center>Company Stock Investment's Forecasting</center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
register_matplotlib_converters()
from time import time
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv('Company Stock and Investment.csv')

# %%
dataset['Date']=pd.to_datetime(dataset['Date'],dayfirst=True)

# %%
# Copying the data
data=dataset

# %%
dataset.set_index('Date',inplace=True)

# %%
dataset.head()
# Out:
#             Oil Investments  Gold Investments  Comp Stock  \
# Date
# 2009-12-31         0.025417          0.000150    0.017354
# 2010-01-04         0.026830          0.001097    0.015565
# 2010-01-05         0.002699          0.001560    0.001729
# 2010-01-06         0.021688          0.006009   -0.015906
# 2010-01-07        -0.006256          0.000221   -0.001849
#
#             Other sharesInvestments
# Date
# 2009-12-31                 0.006848
# 2010-01-04                -0.004609
# 2010-01-05                 0.005900
# 2010-01-06                -0.018116
# 2010-01-07                -0.017013

# %%
# Taking only Oil Investments
data=dataset.drop(['Gold Investments','Comp Stock','Other sharesInvestments'],axis=1)

# %%
data.head()
# Out:
#             Oil Investments
# Date
# 2009-12-31         0.025417
# 2010-01-04         0.026830
# 2010-01-05         0.002699
# 2010-01-06         0.021688
# 2010-01-07        -0.006256

# %% [markdown]
# <h2><b>Visualize the data</b></h2>

# %%
data=data.asfreq('D',method='pad')

# %%
plt.figure(figsize=(10,6))
plt.plot(data)

# %%
data.describe()
# Out:
#        Oil Investments
# count      2877.000000
# mean         -0.000532
# std           0.033754
# min          -1.000000
# 25%          -0.011118
# 50%           0.000399
# 75%           0.010648
# max           0.119511

# %%
data['2017':'2018']
# Out:
#             Oil Investments
# Date
# 2017-01-01        -0.000929
# 2017-01-02        -0.000929
# 2017-01-03        -0.025860
# 2017-01-04         0.017189
# 2017-01-05         0.009576
# ...                     ...
# 2017-11-11        -0.007173
# 2017-11-12        -0.007173
# 2017-11-13         0.000352
# 2017-11-14        -0.019376
# 2017-11-15        -0.007006
#
# [319 rows x 1 columns]

# %%
start_date = datetime(2009,12,31)
end_date = datetime(2017,6,30)

# %%
data=data[start_date:end_date]

# %%
plt.figure(figsize=(10,6))
plt.plot(data)

# %%
from statsmodels.tsa.stattools import adfuller
test_result=adfuller(data)
print(" The Values given as output by adfuller is : \n 'ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'\n\n",test_result)
# Out:
#  The Values given as output by adfuller is :
#  'ADF Test Statistic','p-value','#Lags Used','Number of Observations Used'
#
#  (-24.106298856530188, 0.0, 3, 2735, {'1%': -3.4327432168541914, '5%': -2.862597350432621, '10%': -2.5673328618123117}, -13381.740656568167)

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(data):
    result=adfuller(data) 
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary")
    else:
        print("weak evidence against null hypothesis, time series is non-stationary ")

# %%
adfuller_test(data['Oil Investments'].dropna())
# Out:
# ADF Test Statistic : -24.106298856530188
# p-value : 0.0
# #Lags Used : 3
# Number of Observations Used : 2735
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %%
data.plot()

# %% [markdown]
# As plot shows constant values over time and no specific trend or seasonal representation, so the forecasting cannot be done.

# %%
data=dataset.drop(['Oil Investments','Comp Stock','Other sharesInvestments'],axis=1)

# %%
# Copying the data
datacopy=dataset

# %%
data.head()
# Out:
#             Gold Investments
# Date
# 2009-12-31          0.000150
# 2010-01-04          0.001097
# 2010-01-05          0.001560
# 2010-01-06          0.006009
# 2010-01-07          0.000221

# %%
data=data.resample('M').mean()

# %%
data.describe()
# Out:
#        Gold Investments
# count         96.000000
# mean          -0.019533
# std            0.031323
# min           -0.102125
# 25%           -0.045374
# 50%           -0.001376
# 75%            0.000874
# max            0.005398

# %%
data.plot()

# %% [markdown]
# ###### In above plot data looks like seasonal data, as every year investments goes high. Now we will check if data is stationary or not.

# %%
# Checking the stationarity
adfuller_test(data)
# Out:
# ADF Test Statistic : -4.107779557995698
# p-value : 0.0009402414309088313
# #Lags Used : 11
# Number of Observations Used : 84
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %% [markdown]
# <b><h3>Auto Regressive Model</b></h3>

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(data["Gold Investments"])
plt.show()

# %%
x_train,y_train=data[0:70],data[70:]

# %% [markdown]
# <b>AutoCorrelation and Partial Correlation</b>

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
# First 12 values are null so we will start from 13
fig = plot_acf(x_train,lags=20,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(x_train,lags=20,ax=ax2)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
ts_decompose=seasonal_decompose(y_train,model='additive')
ts_decompose.plot()
plt.plot()
# Out:
# []

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(data,order=(1,0,1)) # this order is p d q(0 or 1) 
model_fit=model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:       Gold Investments   No. Observations:                   96
# Model:                     ARMA(1, 1)   Log Likelihood                 213.976
# Method:                       css-mle   S.D. of innovations              0.026
# Date:                Thu, 17 Dec 2020   AIC                           -419.952
# Time:                        16:51:40   BIC                           -409.694
# Sample:                    12-31-2009   HQIC                          -415.805
#                          - 11-30-2017
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0202      0.000    -47.418      0.000      -0.021      -0.019
# ar.L1.Gold Investments     0.2276      0.131      1.737      0.082      -0.029       0.484
# ma.L1.Gold Investments    -0.8904      0.078    -11.472      0.000      -1.043      -0.738
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            4.3937           +0.0000j            4.3937            0.0000
# MA.1            1.1230           +0.0000j            1.1230            0.0000
# -----------------------------------------------------------------------------
# """

# %%
data['forecast']=model_fit.predict(start=80,end=96,dynamic=True)
data[['Gold Investments','forecast']].plot(figsize=(12,8))

# %%
import statsmodels.api as sm  # SARIMAX - seasonal arimax
model=sm.tsa.statespace.SARIMAX(x_train,order=(1, 1, 0),seasonal_order=(1,1,0,12)) #(p,d,q,Shift)
results=model.fit()

# %%
data['forecast']=results.predict(start=72,end=96,dynamic=True)
data[['Gold Investments','forecast']].plot(figsize=(12,8))

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[data.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=data.columns)

# %%
future_datest_df.tail()
# Out:
#            Gold Investments forecast
# 2019-06-30              NaN      NaN
# 2019-07-30              NaN      NaN
# 2019-08-30              NaN      NaN
# 2019-09-30              NaN      NaN
# 2019-10-30              NaN      NaN

# %%
future_df=pd.concat([data,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 90, end = 120, dynamic= True)  
future_df[['Gold Investments', 'forecast']].plot(figsize=(12, 8))

# %%
# Copying the data
datacopy=dataset

# %%
# Taking only Comp Stock
data=datacopy.drop(['Oil Investments','Gold Investments','Other sharesInvestments'],axis=1)

# %%
# Resample using Month end frequencies
data=data.resample('M').mean()

# %%
data.tail()
# Out:
#             Comp Stock
# Date
# 2017-07-31    0.001640
# 2017-08-31    0.004368
# 2017-09-30   -0.003051
# 2017-10-31    0.004275
# 2017-11-30    0.000092

# %%
data.describe()
# Out:
#        Comp Stock
# count   96.000000
# mean     0.001162
# std      0.003704
# min     -0.006997
# 25%     -0.000842
# 50%      0.000888
# 75%      0.003277
# max      0.017354

# %%
data.plot()

# %%
# Check the tationarity
adfuller_test(data)
# Out:
# ADF Test Statistic : -11.257176132464247
# p-value : 1.6560213346906978e-20
# #Lags Used : 0
# Number of Observations Used : 95
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %% [markdown]
# <b>Auto Correlation</b>

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(data)
plt.show()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
# First 12 values are null so we will start from 13
fig = plot_acf(x_train,lags=20,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(x_train,lags=20,ax=ax2)

# %%
model=ARIMA(data,order=(1,1,0)) # this order is p d q(0 or 1) 
model_fit=model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D.Comp Stock   No. Observations:                   95
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                 380.382
# Method:                       css-mle   S.D. of innovations              0.004
# Date:                Thu, 17 Dec 2020   AIC                           -754.764
# Time:                        17:16:00   BIC                           -747.102
# Sample:                    01-31-2010   HQIC                          -751.668
#                          - 11-30-2017
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -8.484e-05      0.000     -0.289      0.772      -0.001       0.000
# ar.L1.D.Comp Stock    -0.5485      0.098     -5.570      0.000      -0.742      -0.356
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.8230           +0.0000j            1.8230            0.5000
# -----------------------------------------------------------------------------
# """

# %%
data['forecast']=model_fit.predict(start=80,end=96,dynamic=True)
data[['Comp Stock','forecast']].plot(figsize=(12,8))

# %%
model=sm.tsa.statespace.SARIMAX(x_train,order=(1, 0,1),seasonal_order=(1,0,1,12)) #(p,d,q,Shift)
results=model.fit()
data['forecast']=results.predict(start=72,end=96,dynamic=True)
data[['Comp Stock','forecast']].plot(figsize=(12,8))

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[data.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datatest_df=pd.DataFrame(index=future_dates[1:],columns=data.columns)
future_datatest_df.head()
# Out:
#            Comp Stock forecast
# 2017-12-30        NaN      NaN
# 2018-01-30        NaN      NaN
# 2018-02-28        NaN      NaN
# 2018-03-30        NaN      NaN
# 2018-04-30        NaN      NaN

# %%
future_df=pd.concat([data,future_datatest_df])

# %%
future_df['forecast'] = results.predict(start = 90, end = 120, dynamic= True)  
future_df[['Comp Stock', 'forecast']].plot(figsize=(12, 8))

# %%
# Taking only Comp Stock
data=datacopy.drop(['Oil Investments','Gold Investments','Comp Stock'],axis=1)

# %%
# Resampling using Month End frequency
data=data.resample('M').mean()

# %%
data.tail()
# Out:
#             Other sharesInvestments
# Date
# 2017-07-31                 0.001102
# 2017-08-31                -0.000263
# 2017-09-30                -0.000943
# 2017-10-31                 0.006737
# 2017-11-30                 0.001773

# %%
data.describe()
# Out:
#        Other sharesInvestments
# count                96.000000
# mean                  0.001316
# std                   0.003682
# min                  -0.006716
# 25%                  -0.001186
# 50%                   0.001255
# 75%                   0.003771
# max                   0.011160

# %%
data.plot()

# %%
adfuller_test(data)
# Out:
# ADF Test Statistic : -6.297181557412899
# p-value : 3.482721721564751e-08
# #Lags Used : 3
# Number of Observations Used : 92
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data  is stationary

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(data)
plt.show()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
# First 12 values are null so we will start from 13
fig = plot_acf(x_train,lags=20,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(x_train,lags=20,ax=ax2)

# %%
model=ARIMA(data,order=(1,1,0)) # this order is p d q(0 or 1) 
model_fit=model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  ARIMA Model Results
# =====================================================================================
# Dep. Variable:     D.Other sharesInvestments   No. Observations:                   95
# Model:                        ARIMA(1, 1, 0)   Log Likelihood                 374.829
# Method:                              css-mle   S.D. of innovations              0.005
# Date:                       Thu, 17 Dec 2020   AIC                           -743.658
# Time:                               17:22:24   BIC                           -735.996
# Sample:                           01-31-2010   HQIC                          -740.562
#                                 - 11-30-2017
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1.011e-06      0.000     -0.003      0.998      -0.001       0.001
# ar.L1.D.Other sharesInvestments    -0.4809      0.092     -5.236      0.000      -0.661      -0.301
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.0792           +0.0000j            2.0792            0.5000
# -----------------------------------------------------------------------------
# """

# %%
data['forecast']=model_fit.predict(start=80,end=96,dynamic=True)
data[['Other sharesInvestments','forecast']].plot(figsize=(12,8))

# %%
model=sm.tsa.statespace.SARIMAX(x_train,order=(1, 0,1),seasonal_order=(1,0,1,12)) #(p,d,q,Shift)
results=model.fit()
data['forecast']=results.predict(start=72,end=96,dynamic=True)
data[['Other sharesInvestments','forecast']].plot(figsize=(12,8))

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[data.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datatest_data=pd.DataFrame(index=future_dates[1:],columns=data.columns)
future_datatest_data.head()
# Out:
#            Other sharesInvestments forecast
# 2017-12-30                     NaN      NaN
# 2018-01-30                     NaN      NaN
# 2018-02-28                     NaN      NaN
# 2018-03-30                     NaN      NaN
# 2018-04-30                     NaN      NaN

# %%
future_data=pd.concat([data,future_datatest_data])

# %%
future_data['forecast'] = results.predict(start = 90, end = 120, dynamic= True)  
future_data[['Other sharesInvestments', 'forecast']].plot(figsize=(12, 8))
